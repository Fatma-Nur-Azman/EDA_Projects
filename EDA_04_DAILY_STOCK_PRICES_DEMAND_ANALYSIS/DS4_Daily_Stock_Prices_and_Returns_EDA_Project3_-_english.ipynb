# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:dodgerblue;letter-spacing:1px;overflow:hidden"><b> DAILY STOCK DATASET</b></div>
# <p style="text-align: center;"><font color='dodgerblue'> <b>Data Analytics Final Project  | May 2024</b><font color='orange'><p>

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <h3 align="left"><font color=dodgerblue> 🎯 Project Description:</font></h3>
#
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Daily Stock Prices Dataset and Daily Stock Returns Dataset.
# - we will visualize stock prices using Seaborn and Matplotlib.
# - 4 Stocks are considered including JP Morgan Chase (JP), Procter and Gamble (P&G) (PG), Apple (AAPL) and United Airlines (UAL).
#
# <h3 align="left"><font color=dodgerblue> 📝 About the Datasets </font></h3>
#
# **Dataset Descriptions:** 'stocks_daily_prices.csv' / 'stocks_daily_returns.csv'
#
# - **Content:** Daily stock prices for various companies.
# - **Rows:** 3642
# - **Columns:** 5
#     - **Date:** Date of the recorded stock price and returns.
#     - **AAPL**: Daily return for Apple Inc.
#     - **JPM**: Daily return for JPMorgan Chase & Co.
#     - **PG**: Daily return for Procter & Gamble Co.
#     - **UAL**: Daily return for United Airlines Holdings, Inc.
#
# - **Purpose:** These datasets Provide a comprehensive view of stock price movements over time for analysis of trends, patterns, and correlations.
#
# ---
#
# ![image.png](attachment:image.png)
#
# - Apple (AAPL):Apple Inc. is an American multinational technology company known for its innovative electronic products, software, and online services, holding a significant market share worldwide.
#
# - JP Morgan Chase (JP): JP Morgan Chase is an American multinational investment bank and financial services company that provides financial services and is one of the largest banks in the world.
#
# - Procter and Gamble (P&G):  Procter and Gamble is an American-based company that produces many consumer products, such as personal care and cleaning products, as well as healthcare products.
#
# - United Airlines (UAL):  United Airlines is a major airline operating in the United States, with a vast flight network worldwide.
# - **Investment Opportunities**: Despite operating in different sectors, these four companies offer various opportunities to investors, making them attractive options for portfolio diversification.
# ---

# %% [markdown]
# ## <font color=#2865c8> <b> UNDERSTANDING THE DATA </b><font color='orange'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Import The Libraries</b><font color='orange'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

  
# Enable inline plotting
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Import the “kyphosis.csv" file using Pandas
df_prices = pd.read_csv('stocks_daily_prices.csv')
df_returns = pd.read_csv('stocks_daily_returns.csv')

# %% [markdown]
# ### <font color='dodgerblue'> <b> Performing Essential Statistical Analysis on the Dataset </b><font color='orange'>

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
df_prices.head()
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002
# 3  1/7/2008  5.424478  28.868999  47.175980  29.180000
# 4  1/8/2008  5.229351  27.723747  47.299629  24.389999

# %%
df_returns.head()
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %%
df_prices.tail()
# Out:
#            Date        AAPL         JPM          PG        UAL
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999

# %%
df_returns.tail()
# Out:
#            Date      AAPL       JPM        PG        UAL
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824

# %%
df_prices.describe().T
# Out:
#        count       mean        std        min        25%        50%  \
# AAPL  3642.0  39.648625  43.326924   2.387943  11.441511  23.470343
# JPM   3642.0  64.927239  39.662998  11.545819  31.298827  49.601177
# PG    3642.0  73.729653  32.623908  29.637867  46.483078  65.661438
# UAL   3642.0  43.183288  24.392486   3.130000  22.320000  43.080002
#
#             75%         max
# AAPL  45.398705  181.511704
# JPM   95.376392  169.500061
# PG    82.645994  163.410004
# UAL   60.425000   96.699997

# %%
df_returns.describe().T
# Out:
#        count      mean       std        min       25%       50%       75%  \
# AAPL  3642.0  0.105180  2.003500 -17.919513 -0.797108  0.099403  1.129585
# JPM   3642.0  0.069331  2.559122 -20.727418 -0.889705  0.017241  1.002644
# PG    3642.0  0.035579  1.198977  -8.737353 -0.482903  0.037285  0.595436
# UAL   3642.0  0.098866  4.361402 -36.770882 -1.553845  0.016636  1.636975
#
#             max
# AAPL  13.904950
# JPM   25.096737
# PG    12.009046
# UAL   68.537079

# %%
df_prices.duplicated().sum()
# Out:
# 0

# %%
df_returns.duplicated().sum()
# Out:
# 0

# %%
df_prices.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
df_returns.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
# Convert 'Date' column to datetime format on df_prices
df_prices['Date'] = pd.to_datetime(df_prices['Date'])

# %%
# Convert 'Date' column to datetime format on df_return
df_returns['Date'] = pd.to_datetime(df_returns['Date'])

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
# Set 'Date' column as the index
df_prices.set_index('Date', inplace=True)

# %%
# Set 'Date' column as the index
df_returns.set_index('Date',inplace=True)

# %%
df_prices.head()
# Out:
#                 AAPL        JPM         PG        UAL
# Date
# 2008-01-02  5.949703  29.448614  47.058838  29.915234
# 2008-01-03  5.952452  29.246094  47.058838  29.690800
# 2008-01-04  5.498071  28.582682  46.870098  31.000002
# 2008-01-07  5.424478  28.868999  47.175980  29.180000
# 2008-01-08  5.229351  27.723747  47.299629  24.389999

# %%
df_returns.head()
# Out:
#                 AAPL       JPM        PG        UAL
# Date
# 2008-01-02  0.000000  0.000000  0.000000   0.000000
# 2008-01-03  0.046203 -0.687708  0.000000  -0.750233
# 2008-01-04 -7.633517 -2.268378 -0.401072   4.409454
# 2008-01-07 -1.338518  1.001718  0.652615  -5.870973
# 2008-01-08 -3.597157 -3.967066  0.262103 -16.415356

# %% [markdown]
# ##  <font color=#2865c8> <b> DATA VISUALIZATION </b><font color='black'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Visualizing Daily Stock Prices with Line Plots </b><font color='orange'>

# %%
# Plotting the daily prices of the four stocks
plt.figure(figsize=(14, 7))
    
# 1: Plot each stock's daily price 
plt.plot(df_prices.index, df_prices['AAPL'], label='AAPL')
plt.plot(df_prices.index, df_prices['JPM'], label='JPM')
plt.plot(df_prices.index, df_prices['PG'], label='PG')
plt.plot(df_prices.index, df_prices['UAL'], label='UAL')

# 2: Plot each stock's daily price 
# for column in df_prices.columns:
#     plt.plot(df_prices.index, df_prices[column], label=column)

# Add title and labels
plt.title('Daily Prices of AAPL, JPM, PG, and UAL')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Line plots that display all 4 stocks daily prices</font>
#
# The chart can show how certain economic events or significant company news have affected stock prices. For example, the effects of the 2008 financial crisis or the COVID-19 pandemic can be observed.
#
# This type of chart allows investors to visually compare the performance of different stocks and provides insights into which stocks to focus on when diversifying their portfolios.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Subplot with Line Plots of Daily Stock Prices </b><font color='orange'>

# %%
# Create a figure and a set of subplots
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(14, 14), sharex=True)

# 1: Plot each stock's daily price on separate subplots

# AAPL
ax[0].plot(df_prices.index, df_prices['AAPL'], label='AAPL')
ax[0].set_title('Daily Prices of AAPL')
ax[0].set_ylabel('Price')
ax[0].legend()
ax[0].grid(True)

# JPM
ax[1].plot(df_prices.index, df_prices['JPM'], label='JPM')
ax[1].set_title('Daily Prices of JPM')
ax[1].set_ylabel('Price')
ax[1].legend()
ax[1].grid(True)

# PG
ax[2].plot(df_prices.index, df_prices['PG'], label='PG')
ax[2].set_title('Daily Prices of PG')
ax[2].set_ylabel('Price')
ax[2].legend()
ax[2].grid(True)

# UAL
ax[3].plot(df_prices.index, df_prices['UAL'], label='UAL')
ax[3].set_title('Daily Prices of UAL')
ax[3].set_ylabel('Price')
ax[3].legend()
ax[3].grid(True)

#2: Plot each stock's daily price on separate subplots
# for i, column in enumerate(df_prices.columns):
#     axes[i].plot(df_prices.index, df_prices[column], label=column)
#     axes[i].set_title(f'Daily Prices of {column}')
#     axes[i].set_ylabel('Price')
#     axes[i].legend()
#     axes[i].grid(True)

# Add a common x-axis label
plt.xlabel('Date')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: lineplots that display all 4 stocks daily prices</font>
#
# This chart displays the daily prices of four different stocks (AAPL, JPM, PG, UAL) in separate subplots. Apple (AAPL) and JP Morgan (JPM) typically show higher volatility, while Procter & Gamble (PG) is more stable with lower volatility. United Airlines (UAL), being sensitive to fluctuations in the airline industry, shows larger price changes. Such charts help investors compare the performance of stocks and gain insights into which stocks to focus on when diversifying their portfolios.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Scatter Plot of Daily Stock Prices</b><font color='orange'>

# %%
# Plot the scatter plot between Apple and JP Morgan daily returns
plt.figure(figsize=(10, 6))

plt.scatter(df_returns['AAPL'], df_returns['JPM'], c='blue', alpha=0.5, label='Apple')
plt.scatter(df_returns['JPM'], df_returns['AAPL'], c='brown', alpha=0.5, label='JP Morgan')

plt.title('Scatter Plot between Apple and JP Morgan Daily Returns')
plt.xlabel('Apple Daily Returns')
plt.ylabel('JP Morgan Daily Returns')
plt.grid(True)

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Scatter Plot</font>
#
# This chart shows the relationship between the daily returns of Apple (AAPL) and JP Morgan (JPM). The density of the points indicates that the returns of both stocks generally exhibit low changes and large fluctuations are rare. The spread suggests high volatility in returns and occasional large changes. Positive correlation shows a positive relationship between Apple and JP Morgan returns. Such a chart helps investors compare the performance of these stocks and make more informed portfolio diversification decisions.

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Pie Chart</font>
#
# This pie chart shows the asset allocation in the portfolio. AAPL holds the largest share at 40%, followed by JPM at 25%, PG at 20%, and UAL at 15%. AAPL is separated from the rest using the 'explode' feature, indicating the investor's high confidence and high return expectation in Apple. The chart visually presents the diversification and the risk-return balance in the portfolio.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Histogram of Daily Stock Prices</b><font color='orange'>

# %%
# Display the mean and standard deviation for both stocks on top of the figure.

# Calculate the mean and standard deviation for UAL and PG returns
ual_mean = df_returns['UAL'].mean()
ual_std = df_returns['UAL'].std()
pg_mean = df_returns['PG'].mean()
pg_std = df_returns['PG'].std()

# Plot the histograms for UAL and PG returns
plt.figure(figsize=(10, 5))

# Histogram for UAL
plt.subplot(1, 2, 1)
plt.hist(df_returns['UAL'], bins=40, color='red', alpha=0.7)
plt.title(f'UAL Returns\nMean: {ual_mean:.2f}, Std: {ual_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

# Histogram for PG
plt.subplot(1, 2, 2)
plt.hist(df_returns['PG'], bins=40, color='red', alpha=0.7)
plt.title(f'PG Returns\nMean: {pg_mean:.2f}, Std: {pg_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Histogram</font>
#
# These charts show the distribution of daily returns for United Airlines (UAL) and Procter & Gamble (PG) stocks. UAL returns are spread over a wider range, indicating higher volatility and risk, while PG returns are more concentrated within a narrower range, indicating lower volatility and more stable returns.

# %% [markdown]
# ##  <font color=#2865c8> <b> CORRELATIONS AND RELATIONSHIPS </b><font color='black'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Visualizing Stock Correlations with a Heatmap</b><font color='orange'>

# %%
# Calculate the correlation matrix
correlation_matrix = df_returns.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Stocks Daily Returns')
plt.show()

# Comment on the correlation between UAL and PG
ual_pg_correlation = correlation_matrix.loc['UAL', 'PG']
print(f'The correlation between UAL and PG is: {ual_pg_correlation:.4f}')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# The correlation between UAL and PG is: 0.2382

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Heatmap</font>
# This chart shows the correlations between the daily returns of four stocks. There is a strong positive correlation between Apple (AAPL) and JP Morgan (JPM), while United Airlines (UAL) and Procter & Gamble (PG) have a low positive correlation (0.2444). This indicates that UAL and PG returns generally move independently, which is beneficial for portfolio diversification.

# %% [markdown]
# ##  <font color=#2865c8> <b> Investment Performance and Portfolio Analysis </b><font color='black'>

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue></font>
#
# In this section, we analyze the performance of a $1000 investment in each stock over a specific time period (January 3, 2017 - June 1, 2022). This analysis visualizes the change in the value of the investment over time and the final composition of the portfolio.
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df_prices = pd.read_csv('stocks_daily_prices.csv')
df_returns = pd.read_csv('stocks_daily_returns.csv')

# Convert 'Date' column to datetime format
df_prices['Date'] = pd.to_datetime(df_prices['Date'])
df_returns['Date'] = pd.to_datetime(df_returns['Date'])

# Set 'Date' column as index
df_prices.set_index('Date', inplace=True)
df_returns.set_index('Date', inplace=True)

# Initial investment amount
initial_investment = 1000

# Calculation for a specific time period (January 3, 2017 - June 1, 2022)
start_date = '2017-01-03'
end_date = '2022-06-01'

# Initial stock prices
initial_prices_period = df_prices.loc[start_date, ['AAPL', 'JPM', 'PG', 'UAL']]

# Number of units purchased for each stock
units_period = initial_investment / initial_prices_period

# Calculate portfolio value for each stock over the specific time period
subset_portfolio_values = df_prices.loc[start_date:end_date, ['AAPL', 'JPM', 'PG', 'UAL']].mul(units_period, axis=1)
subset_portfolio_values['Total'] = subset_portfolio_values.sum(axis=1)
subset_portfolio_values.reset_index(inplace=True)

# Calculate total profit/loss
initial_total_investment_period = 4 * initial_investment
final_total_value_period = subset_portfolio_values.iloc[-1]['Total']
total_profit_loss_period = final_total_value_period - initial_total_investment_period

# Create the plots
fig, ax = plt.subplots(2, 1, figsize=(14, 14))

# Plot for the specific time period
ax[0].plot(subset_portfolio_values['Date'], subset_portfolio_values['AAPL'], label='AAPL')
ax[0].plot(subset_portfolio_values['Date'], subset_portfolio_values['JPM'], label='JPM')
ax[0].plot(subset_portfolio_values['Date'], subset_portfolio_values['PG'], label='PG')
ax[0].plot(subset_portfolio_values['Date'], subset_portfolio_values['UAL'], label='UAL')
ax[0].plot(subset_portfolio_values['Date'], subset_portfolio_values['Total'], label='Total', linewidth=2, linestyle='--')

ax[0].set_title('Investment Performance of $1000 in Each Stock (Jan 3, 2017 - Jun 1, 2022)')
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Portfolio Value ($)')
ax[0].legend()
ax[0].grid(True)
ax[0].annotate(f'Total Profit/Loss: {total_profit_loss_period:.2f}$', xy=(0.15, 0.95), xycoords='axes fraction', fontsize=12,
               bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='yellow'))

# Pie chart for final portfolio distribution and text
final_values = subset_portfolio_values.iloc[-1][['AAPL', 'JPM', 'PG', 'UAL']]

# Define text properties for percentage labels
textprops = {'fontsize': 16}

ax[1].pie(final_values, labels=final_values.index, autopct='%1.1f%%', startangle=140, colors=['blue', 'green', 'red', 'purple'], textprops=textprops)
ax[1].set_title('Final Portfolio Distribution (Jan 3, 2017 - Jun 1, 2022)')

# Add text for financial summary
textstr = '\n'.join((
    f'Initial Investment: ${initial_total_investment_period:,.2f}',
    f'Total Profit: ${total_profit_loss_period:,.2f}',
    f'Total Portfolio Value: ${final_total_value_period:,.2f}'
))

props = dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white')

# Place text next to the pie chart
ax[1].text(1.05, 0.5, textstr, transform=ax[1].transAxes, fontsize=12,
           verticalalignment='center', bbox=props)

plt.tight_layout()
plt.savefig('portfolio_analysis_with_pie_chart_and_text_specific_period_en.png')
plt.show()
